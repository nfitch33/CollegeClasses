# %%
let x = 10 in 
  x == 10
# Out:
# - : bool = true

# %%
let x : int = 3200 in
let _ = print_string("Hello World!\n") in
let _ = print_string("from CompSci") in
let _ = print_int(x) in
  print_string("\n");
  print_string("from CS " ^ string_of_int x ^ "\n")
# Out:
# - : unit = ()

# %% [markdown]
# # 2.3.2 structural equality (`=` and `<>`) and physical equality (`==` and `!=`)
#
# * Helpful link: https://stackoverflow.com/questions/13590307/whats-the-difference-between-equal-and-identical-in-ocaml
#
# * Caution: the semantics of equality operators depend on whether the variable is mutable.

# %%
42 = 42
# Out:
# - : bool = true

# %%
42 == 42
# Out:
# - : bool = true

# %%
let x = 42 in 
    x == 42
# Out:
# - : bool = true

# %%
let x = 42 in 
    x = 42
# Out:
# - : bool = true

# %%
let x = 42 in
let y = 42 in
x = y
# Out:
# - : bool = true

# %%
let x = 42 in
let y = 42 in
x == y
# Out:
# - : bool = true

# %%
let x = [1; 2] in
let y = [1; 2] in 
x = y
# Out:
# - : bool = true

# %% [markdown]
# # Eqality for lists

# %%
[]
# Out:
# - : 'a list = []

# %%
[1]
# Out:
# - : int list = [1]

# %%
[1; 2]
# Out:
# - : int list = [1; 2]

# %%
[1.0; 2.0; 3.0]
# Out:
# - : float list = [1.; 2.; 3.]

# %%
[1; 2; 3]
# Out:
# - : int list = [1; 2; 3]

# %%
let x = [1; 2] in
    x = [1; 2]
# Out:
# - : bool = true

# %%
let x = [1; 2] in
    x == [1; 2]
# Out:
# - : bool = false

# %%
let x = [1; 2] in
let y = [1; 2] in 
  x = y
# Out:
# - : bool = true

# %%
let x = [1; 2] in
let y = [1; 2] in 
  x == y
# Out:
# - : bool = false

# %%
let x = [1; 2] in
let y = x in 
  x == y
# Out:
# - : bool = true

# %%
let x = [1; 2] in
x = [1; 2]
# Out:
# - : bool = true

# %%
let x = [1; 2] in
x == [1; 2]
# Out:
# - : bool = false

# %% [markdown]
# # Scope

# %%
let x = 6 in (let x = 5 in x) + x
# Out:
# - : int = 11

# %% [markdown]
# # Recursive Function

# %%
let rec fib n =
  if n <= 1 then n
  else fib (n-1) + fib (n-2)
# Out:
# val fib : int -> int = <fun>

# %%
fib(1)
# Out:
# - : int = 1

# %%
fib(2)
# Out:
# - : int = 1

# %%
fib(5)
# Out:
# - : int = 5

# %%
fib(10)
# Out:
# - : int = 55

# %%
fib(20)
# Out:
# - : int = 6765
